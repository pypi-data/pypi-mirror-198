# %%
import json as json
from mrftools.sequenceParameters import *
from mrftools import Units
with open("YongSequence.json") as inputFile:
    inputJson = json.load(inputFile)
    sequenceParameters = SequenceParameters.FromJson(inputJson)
    print(sequenceParameters)
# Out:
# 2023-02-27 13:53:41.533936: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-27 13:53:41.721734: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-02-27 13:53:42.539009: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# ...

# %%
exportFilename = "exportTest.json"
with open(exportFilename, 'w') as outfile:
    json.dump(sequenceParameters.__dict__(), outfile, indent=2)

# %%
with open(exportFilename) as inputFile:
    inputJson = json.load(inputFile)
    sequenceParameters = SequenceParameters.FromJson(inputJson)
    print(sequenceParameters)
# Out:
# Input file mrttools Version: 0.2.1
# Sequence: YongSequence
# Modules:
# ------------------
# Module Type: PREPARATION || Preparation Type: RF || RF Type: INVERSION || Total Duration (s): 0.02000 || RF Duration (s): 0.00000 || RF Phase (degrees): 0.00000
# ------------------
# Module Type: ACQUISITION || Acquisition Type: FISP || Dephasing Range (# of pi): 2.00000 || Timepoints:
# [(10., 2., 10., 0., 0) (10., 2., 11., 0., 1) (10., 2., 12., 0., 2)
#  (10., 2., 13., 0., 3) (10., 2., 14., 0., 4)]
# ------------------
# Module Type: RECOVERY || Recovery Type: DEADTIME || Total Duration (s): 0.30000
# ------------------
# Module Type: ACQUISITION || Acquisition Type: FISP || Dephasing Range (# of pi): 2.00000 || Timepoints:
# [(10., 2., 10., 0., 0) (10., 2., 11., 0., 1) (10., 2., 12., 0., 2)
#  (10., 2., 13., 0., 3) (10., 2., 14., 0., 4)]
# ------------------
# Module Type: RECOVERY || Recovery Type: DEADTIME || Total Duration (s): 0.30000
# ------------------
# ...

# %%
sequenceParameters.ExportToJson()
